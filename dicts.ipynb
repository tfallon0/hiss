# %%
d = {}
d['a'] = 5

# %%
d['a']
# Out:
# 5

# %%
d['b']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /workspaces/hiss/dicts.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bsuper-barnacle-75q47x6ggw63pg5j/workspaces/hiss/dicts.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> d['b']
#
# KeyError: 'b'

# %%
try:
    x = d['b']
except KeyError:
    x = 42

# %%
x
# Out:
# 42

# %%
d['c'] = 12
d['d'] = 15

# %%
set(d)
# Out:
# {'a', 'c', 'd'}

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
sorted(["hello", "nz", "world", "bw", "asdasdasdasd", "aaaaa", "bw", "a-aron", "za"], key=len)
# Out:
# ['nz', 'bw', 'bw', 'za', 'hello', 'world', 'aaaaa', 'a-aron', 'asdasdasdasd']

# %%
type(id({1,2,3}))
# Out:
# int

# %%
id()
