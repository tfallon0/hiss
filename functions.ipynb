# %%
def square(x):
    return x**2

# %%
square(5)
# Out:
# 25

# %%
square
# Out:
# <function __main__.square(x)>

# %%
lambda x: x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x: x**2)(5)
# Out:
# 25
